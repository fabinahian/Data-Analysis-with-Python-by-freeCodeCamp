# %% [markdown]
# <a href="https://www.kaggle.com/code/fabinahian/pandas-basics?scriptVersionId=130883147" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Series (Concept)

# %%
# Elements of a series is indexed

#In millions:
g7_pop = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523]) #The Group of Seven: Canada, France, Germany, Italy, Japan, the UK, the USA

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
# We can name serieses for better documentation

g7_pop.name = 'G7 Population in Millions'

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
g7_pop.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %%
type(g7_pop.values)
# Out:
# numpy.ndarray

# %%
# Inexing works with Series

print(g7_pop)
print("first element: ",g7_pop[0])
print("second element: ", g7_pop[1])
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64
# first element:  35.467
# second element:  63.951

# %%
#We can re-define the indexes in Pandas Series

g7_pop.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'
]

g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Creating a Series from Scratch

# %%
pd.Series({
    'Canada': 35.467,
    'France': 63.951,
    'Germany': 80.94,
    'Italy': 60.665,
    'Japan': 127.061,
    'United Kingdom': 64.511,
    'United States': 318.523
}, name= 'G7 Population in Millions')
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
pd.Series([35.467, 63.951,  80.94, 60.665, 127.061, 64.511, 318.523],
         index = ['Canada', 'France', 'Germany', 'Italy', 'Japan', 'united Kingdom', 'United States'],
         name = 'G7 Population in Millions')
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# united Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
# You can also create Series out of other Series, specifying indexes

pd.Series(g7_pop, index=['France', 'Germany', 'Italy', 'Spain'])
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Spain         NaN
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Indexing

# %%
g7_pop['Canada']
# Out:
# 35.467

# %%
g7_pop['Japan']
# Out:
# 127.061

# %%
g7_pop.iloc[0]
# Out:
# 35.467

# %%
g7_pop.iloc[-1]
# Out:
# 318.523

# %%
g7_pop[['Italy','France']] # result will be a new Series
# Out:
# Italy     60.665
# France    63.951
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.iloc[[0,1,2]]
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Name: G7 Population in Millions, dtype: float64

# %%
# Series also support slicing but unlike Python, it INCLUDES the upper limit.

g7_pop['Canada':'Italy']
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Conditional Selection (Boolean Arrays)

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop>70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[g7_pop>70]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
g7_pop[ g7_pop>g7_pop.mean()]
# Out:
# Japan            127.061
# United States    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.std()
# Out:
# 97.24996987121581

# %%
g7_pop[(g7_pop > g7_pop.mean() - g7_pop.std()) | (g7_pop > g7_pop.mean()  + g7_pop.std())]
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Operations & Methods

# %%
g7_pop + 100
# Out:
# Canada            135.467
# France            163.951
# Germany           180.940
# Italy             160.665
# Japan             227.061
# United Kingdom    164.511
# United States     418.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
np.log(g7_pop)
# Out:
# Canada            3.568603
# France            4.158117
# Germany           4.393708
# Italy             4.105367
# Japan             4.844667
# United Kingdom    4.166836
# United States     5.763695
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop['France': 'Italy'].mean()
# Out:
# 68.51866666666666

# %% [markdown]
# # Boolean Arrays

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop > 80
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[g7_pop>80]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[(g7_pop>80) | (g7_pop<40)]
# Out:
# Canada            35.467
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[(g7_pop>80) & (g7_pop<400)]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# # Modifying Series

# %%
g7_pop['Canada'] = 40.5

# %%
g7_pop
# Out:
# Canada             40.500
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.iloc[-1]= 500

# %%
g7_pop
# Out:
# Canada             40.500
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     500.000
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[g7_pop<70]=99.99

# %%
g7_pop
# Out:
# Canada             99.990
# France             99.990
# Germany            80.940
# Italy              99.990
# Japan             127.061
# United Kingdom     99.990
# United States     500.000
# Name: G7 Population in Millions, dtype: float64
